# %%
from sisl import *

# %%
molecule=Geometry.read("molecula.xyz")

# %%
molecule.plot()

# %%
molecule.write("structure.fdf")

# %%
structure=Geometry.read("structure.fdf")

# %%
structure.plot()
